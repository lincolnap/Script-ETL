# %% [markdown]
# # Connection to DB

# %%
import sqlalchemy as sql
import pandas as pd

# %%
try:
    engine = sql.create_engine('mssql+pymssql://data11:12345*@192.168.3.16:1433/AdventureWorks2019')
    print('connecxion extablecida')
except: 
    print('connexion fallida')
# Out:
# connecxion extablecida

# %%
query ="""SELECT [TransactionID]
                ,[ProductID]
                ,[ReferenceOrderID]
                ,[ReferenceOrderLineID]
                ,[TransactionDate]
                ,[TransactionType]
                ,[Quantity]
                ,[ActualCost]
                ,[ModifiedDate]
            FROM [AdventureWorks2019].[Production].[TransactionHistory]"""

# %% [markdown]
# # Leyendo la tabla de una consulta

# %%
#Leyendo la tabla de una consulta
df = pd.read_sql_table('Product', engine,schema='Production')
df.head(5)
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0          1        Adjustable Race       AR-5381     False
# 1          2           Bearing Ball       BA-8327     False
# 2          3        BB Ball Bearing       BE-2349      True
# 3          4  Headset Ball Bearings       BE-2908     False
# 4        316                  Blade       BL-2036      True
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0              False  None              1000           750           0.0
# 1              False  None              1000           750           0.0
# 2              False  None               800           600           0.0
# 3              False  None               800           600           0.0
# 4              False  None               800           600           0.0
#
#    ListPrice  ... ProductLine Class Style  ProductSubcategoryID  \
# 0        0.0  ...        None  None  None                   NaN
# ...

# %% [markdown]
# # Ejecutando un query con pandas

# %%
#Ejecutando un query
df2 = pd.read_sql_query(query,engine,index_col='TransactionID')
df2.tail(5)
# Out:
#                ProductID  ReferenceOrderID  ReferenceOrderLineID  \
# TransactionID
# 213438               332              3998                     1
# 213439               907              3999                     2
# 213440               948              3999                     1
# 213441               325              4000                     1
# 213442               326              4000                     2
#
#               TransactionDate TransactionType  Quantity  ActualCost  \
# TransactionID
# 213438             2014-08-03               P       550     10.8150
# 213439             2014-08-03               P       550     82.8345
# 213440             2014-08-03               P       550     82.8345
# 213441             2014-08-03               P      1250      0.2100
# 213442             2014-08-03               P      1250      0.2100
#
#               ModifiedDate
# TransactionID
# 213438          2014-08-03
# 213439          2014-08-03
# 213440          2014-08-03
# ...
